# %%
import csv
#               THIS IS PERFECT
place_name="HUANCAVELICA"


file_path = f'D://uw//data//{place_name}//details.txt'

import ast

# Read data from the text file and store it in the 'data' variable

with open(file_path, 'r', encoding='utf-8') as file:
    file_content = file.read()

# Add square brackets to the content to make it a valid list
file_content_with_brackets = f"[{file_content}]"

# Safely evaluate the string as a Python literal (list of dictionaries)
data = ast.literal_eval(file_content_with_brackets)
# Extract all unique keys
all_keys = set()
for entry in data:
    all_keys.update(entry.keys())

# Sort the keys for consistent column order in the CSV
sorted_keys = sorted(all_keys)

# Write to CSV file
csv_file_path = f'D://uw//data//{place_name}//clean.csv'
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    csv_writer = csv.DictWriter(csv_file, fieldnames=sorted_keys)
    
    # Write header
    csv_writer.writeheader()
    
    # Write rows
    for entry in data:
        row_data = {key: entry.get(key, '') for key in sorted_keys}
        csv_writer.writerow(row_data)

print(f"CSV file has been created at: {csv_file_path}")
# Out:
# CSV file has been created at: D://uw//data//HUANCAVELICA//clean.csv

# %%
file_path = f'D://uw//data//{place_name}//details.txt'

import ast

# Read data from the text file and store it in the 'data' variable

with open(file_path, 'r', encoding='utf-8') as file:
    file_content = file.read()

# Add square brackets to the content to make it a valid list
file_content_with_brackets = f"[{file_content}]"

# Safely evaluate the string as a Python literal (list of dictionaries)
data = ast.literal_eval(file_content_with_brackets)

# %%
data
# Out:
# [{'RUC': '20602319041',
#   'Razón Social': 'SIACDI S.A.C.',
#   'Tipo Empresa': 'Sociedad Anonima Cerrada',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '01 / Agosto / 2017',
#   'Actividades Comerciales': 'Cultivo de Hortalizas y Legumbres. Otras Activid.de Tipo Servicio Ncp',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Manual',
#   'Tipo de Contabilidad': 'Manual/computarizado',
#   'Dirección Legal': 'Cal. Choquehuanca Nro. S/n Bar. Acobamba',
#   'Distrito / Ciudad': 'Acobamba',
#   'Provincia': 'Acobamba',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20605501347',
#   'Razón Social': 'COMUNIDAD CAMPESINA DE HUAYANAY',
#   'Tipo Empresa': 'Comunidad Campesina Nativa',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '12 / Noviembre / 2019',
#   'Actividad Comercial': 'Cultivo de Hortalizas y Legumbres.',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Manual/computarizado',
#   'Tipo de Contabilidad': 'Manual/computarizado',
#   'Dirección Legal': 'Av. Libertadores Mz. T Lote 16 ---- C.Cam Huayanay',
#   'Distrito / Ciudad': 'Anta',
#   'Provincia': 'Acobamba',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20605501223',
#   'Razón Social': 'COMUNIDAD CAMPESINA DE TAMBRAICO',
#   'Tipo Empresa': 'Comunidad Campesina Nativa',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '12 / Noviembre / 2019',
#   'Actividad Comercial': 'Cultivo de Hortalizas y Legumbres.',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Manual/computarizado',
#   'Tipo de Contabilidad': 'Manual/computarizado',
#   'Dirección Legal': 'Nro. Sn ---- C. Camp. Tambraico',
#   'Distrito / Ciudad': 'Anta',
#   'Provincia': 'Acobamba',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20611027215',
#   'Razón Social': 'ASOCIACIÓN DE PRODUCTORES AGROPECUARIOS LOS ILLAPAS DE CHANQUIL-ROSARIO',
#   'Tipo Empresa': 'Asociacion',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '01 / Junio / 2023',
#   'Actividades Comerciales': 'Cultivo de Hortalizas y Legumbres. Cultivos de Cereales.',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Manual/computarizado',
#   'Tipo de Contabilidad': 'Manual/computarizado',
#   'Dirección Legal': 'Nro. Sn C.C. Chanquil',
#   'Distrito / Ciudad': 'Rosario',
#   'Provincia': 'Acobamba',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20608571648',
#   'Razón Social': 'ASOCIACION DE PRODUCTORES AGROPECUARIOS UNION CHANQUIL',
#   'Tipo Empresa': 'Asociacion',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '05 / Octubre / 2021',
#   'Actividades Comerciales': 'Cultivo de Hortalizas y Legumbres. Actividades Otras Asociaciones Ncp.',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Manual/computarizado',
#   'Tipo de Contabilidad': 'Manual/computarizado',
#   'Dirección Legal': 'Cal. Lima Nro. Sn C.P. Chanquil',
#   'Distrito / Ciudad': 'Rosario',
#   'Provincia': 'Acobamba',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20607939692',
#   'Razón Social': 'ASOCIACIÓN DE PRODUCTORES AGROPECUARIOS VALLE LOS GUINDALES PATA',
#   'Tipo Empresa': 'Asociacion',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '20 / Mayo / 2021',
#   'Actividades Comerciales': 'Cultivo de Hortalizas y Legumbres. Construccion Edificios Completos.',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Manual',
#   'Tipo de Contabilidad': 'Manual',
#   'Dirección Legal': 'Pza. Principal Nro. S/n C.P. Pitinpata',
#   'Distrito / Ciudad': 'Lircay',
#   'Provincia': 'Angaraes',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20607948101',
#   'Razón Social': 'ASOCIACIÓN DE PRODUCTORES AGROPECUARIOS Y MULTISERVICIOS HUERTO DE LAS ROSAS',
#   'Tipo Empresa': 'Asociacion',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '12 / Mayo / 2021',
#   'Actividad Comercial': 'Cultivo de Hortalizas y Legumbres.',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Manual',
#   'Tipo de Contabilidad': 'Manual',
#   'Dirección Legal': 'Nro. S/n Anx. los Angeles',
#   'Distrito / Ciudad': 'Lircay',
#   'Provincia': 'Angaraes',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20601848903',
#   'Razón Social': 'COMUNIDAD CAMPESINA DE SANTO TOMAS DE PATA Y ANEXOS DE ANTA Y MESACCOCHA',
#   'Tipo Empresa': 'Comunidad Campesina Nativa',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '02 / Febrero / 2017',
#   'Actividad Comercial': 'Cultivo de Hortalizas y Legumbres.',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Manual',
#   'Tipo de Contabilidad': 'Manual',
#   'Dirección Legal': 'Nro. S/n ---- Bq Santo Tomas de Pata',
#   'Distrito / Ciudad': 'Santo Tomas de Pata',
#   'Provincia': 'Angaraes',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20611702133',
#   'Razón Social': 'ASOCIACION AGROPECUARIA NUEVA GENERACION DE COMUHUILLCA',
#   'Tipo Empresa': 'Asociacion',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '18 / Octubre / 2023',
#   'Actividad Comercial': 'Cultivo de Hortalizas y Legumbres.',
#   'CIIU': '01123',
#   'Dirección Legal': 'Pza. Principal Nro. Sn Anx. Comuhuillca',
#   'Distrito / Ciudad': 'Paucarbamba',
#   'Provincia': 'Churcampa',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20605093745',
#   'Razón Social': 'ASOCIACION DE PRODUCTORES AGROPECUARIOS FAMILIA ABREGU DE HUARIBAMBILLA',
#   'Tipo Empresa': 'Asociacion',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '08 / Febrero / 2023',
#   'Actividades Comerciales': 'Cultivo de Hortalizas y Legumbres. Otras Activid.de Tipo Servicio Ncp',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Manual/computarizado',
#   'Tipo de Contabilidad': 'Manual/computarizado',
#   'Dirección Legal': 'Nro. S/n Anx. Huaribambilla',
#   'Distrito / Ciudad': 'Paucarbamba',
#   'Provincia': 'Churcampa',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20606374811',
#   'Razón Social': 'ASOC. DE PRODUCTORES Y PRODUCTORAS AGROPEC. AGROECOLOGICO FORESTAL LOS INNOVADORES RIKCHARY LLAQTA',
#   'Tipo Empresa': 'Asociacion',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '07 / Febrero / 2023',
#   'Actividades Comerciales': 'Cultivo de Hortalizas y Legumbres. Explotacion Mixta. Actividades Otras Asociaciones Ncp.',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Manual/computarizado',
#   'Tipo de Contabilidad': 'Manual/computarizado',
#   'Dirección Legal': 'Pza. Principal Nro. S/n Anx. Vizcapata',
#   'Distrito / Ciudad': 'Huando',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20606616121',
#   'Razón Social': 'COMUNIDAD CAMPESINA DE LARMENTA',
#   'Tipo Empresa': 'Comunidad Campesina Nativa',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '29 / Septiembre / 2020',
#   'Actividad Comercial': 'Cultivo de Hortalizas y Legumbres.',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Manual',
#   'Tipo de Contabilidad': 'Manual',
#   'Dirección Legal': 'Pq. Principal Mz. L Lote 10 Anx. la Armenta Etapa',
#   'Distrito / Ciudad': 'Izcuchaca',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20611560967',
#   'Razón Social': 'ASOC. DE PROD. AGROP. Y SERV. MULT. TUBERCULOS ANDINOS DE NUEVO OCCORO-APATANO DIST. NUEVO OCCO',
#   'Tipo Empresa': 'Asociacion',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '18 / Septiembre / 2023',
#   'Actividades Comerciales': 'Cultivo de Hortalizas y Legumbres. Actividades Otras Asociaciones Ncp.',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Manual/computarizado',
#   'Tipo de Contabilidad': 'Manual/computarizado',
#   'Dirección Legal': 'Jr. 10 de Mayo Nro. Sn',
#   'Distrito / Ciudad': 'Nuevo Occoro',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20609151839',
#   'Razón Social': 'COMUNIDAD CAMPESINA DE OCCORO VIEJO',
#   'Tipo Empresa': 'Comunidad Campesina Nativa',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '01 / Marzo / 2022',
#   'Actividades Comerciales': 'Cultivo de Hortalizas y Legumbres. Explotacion Mixta.',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Manual/computarizado',
#   'Tipo de Contabilidad': 'Manual/computarizado',
#   'Dirección Legal': 'Av. Huancavelica Nro. Sn ---- Pueblo Occoro Viejo',
#   'Distrito / Ciudad': 'Nuevo Occoro',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20601450667',
#   'Razón Social': 'COMUNIDAD CAMPESINA DE HUAYACUNDO ARMA',
#   'Tipo Empresa': 'Comunidad Campesina Nativa',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '24 / Agosto / 2016',
#   'Actividades Comerciales': 'Cultivo de Hortalizas y Legumbres. Cria de Ganado. Cria de Animales Domesticos.',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Manual',
#   'Tipo de Contabilidad': 'Manual',
#   'Dirección Legal': 'Cal. Santa Teresita Nro. S/n',
#   'Distrito / Ciudad': 'Huayacundo Arma',
#   'Provincia': 'Huaytara',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20602160247',
#   'Razón Social': 'ASOC. DE PROD. AGROP. ECOL. Y SERV. MULT. NUEVO AMANECER DEL ANEX. DE RUDIOPAMPA, DISTR. DE AHUAYCHA',
#   'Tipo Empresa': 'Asociacion',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '01 / Junio / 2017',
#   'Actividad Comercial': 'Cultivo de Hortalizas y Legumbres.',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Manual',
#   'Tipo de Contabilidad': 'Manual',
#   'Dirección Legal': 'Plaza Principal Nro. S/n Anx. Rudiopampa',
#   'Distrito / Ciudad': 'Ahuaycha',
#   'Provincia': 'Tayacaja',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20610630791',
#   'Razón Social': 'ASOCIACION DE SERVICIOS MULTIPLES VALLADOLID P.',
#   'Tipo Empresa': 'Asociacion',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '01 / Marzo / 2023',
#   'Actividad Comercial': 'Cultivo de Hortalizas y Legumbres.',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Manual',
#   'Tipo de Contabilidad': 'Manual',
#   'Dirección Legal': 'Sector Quintao Mz. L Lote 024 ---- C. Camp. Quintao',
#   'Distrito / Ciudad': 'Andaymarca',
#   'Provincia': 'Tayacaja',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20609922151',
#   'Razón Social': 'ASOCIACIÓN DE PRODUCTORES AGROPECUARIOS Y SERVICIOS MÚLTIPLES SANTA FE DE JABONILLO - COLCABAMBA',
#   'Tipo Empresa': 'Asociacion',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '25 / Agosto / 2022',
#   'Actividad Comercial': 'Cultivo de Hortalizas y Legumbres.',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Manual',
#   'Tipo de Contabilidad': 'Manual',
#   'Dirección Legal': 'Car. Vista Alegre Jabonillo Nro. Sn C.P. Santa Fe de Jabonillo',
#   'Distrito / Ciudad': 'Colcabamba',
#   'Provincia': 'Tayacaja',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20610924621',
#   'Razón Social': 'ASOCIACION DE PRODUCTORES RENACIENDO EN UN NUEVO POR VENIR EN NUESTRA TIERRA ZARZAPAMPA & POCYACC',
#   'Tipo Empresa': 'Asociacion',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '27 / Abril / 2023',
#   'Actividad Comercial': 'Cultivo de Hortalizas y Legumbres.',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Manual/computarizado',
#   'Tipo de Contabilidad': 'Manual/computarizado',
#   'Dirección Legal': 'Car. Amaru Libertad Nro. 007',
#   'Distrito / Ciudad': 'Colcabamba',
#   'Provincia': 'Tayacaja',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20601718180',
#   'Razón Social': 'ASOCIACION DE PRODUCTORES AGROPECUARIOS LOS LIDERES COMUNIDAD CAMPESINA SAN JUAN DE CHICCHICANCHA',
#   'Tipo Empresa': 'Asociacion',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '01 / Abril / 2018',
#   'Actividad Comercial': 'Cultivo de Hortalizas y Legumbres.',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Manual',
#   'Tipo de Contabilidad': 'Manual',
#   'Dirección Legal': 'Nro. S/n Anx. Chicchicancha',
#   'Distrito / Ciudad': 'Huaribamba',
#   'Provincia': 'Tayacaja',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20605222839',
#   'Razón Social': 'COMUNIDAD CAMPESINA DE CALLACASA',
#   'Tipo Empresa': 'Comunidad Campesina Nativa',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '06 / Septiembre / 2019',
#   'Actividades Comerciales': 'Cultivo de Hortalizas y Legumbres. Cultivos de Cereales.',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Manual/computarizado',
#   'Tipo de Contabilidad': 'Manual/computarizado',
#   'Dirección Legal': 'Pza. Principal Nro. Sn Anx. Callacasa',
#   'Distrito / Ciudad': 'ñahuimpuquio',
#   'Provincia': 'Tayacaja',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20603214600',
#   'Razón Social': 'ASOC PROD PLANTAS FOR Y AGRIC PROSP AMB-APFAPA COM UYROS PAMPA-MUTUY PATA DIST PAMPAS-TAYACAJA-HVCA',
#   'Tipo Empresa': 'Asociacion',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '22 / Mayo / 2018',
#   'Actividad Comercial': 'Cultivo de Hortalizas y Legumbres.',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Manual/computarizado',
#   'Tipo de Contabilidad': 'Manual/computarizado',
#   'Dirección Legal': 'Pq. Uyrus Lote 024 Bar. Uyrus Alto',
#   'Distrito / Ciudad': 'Pampas',
#   'Provincia': 'Tayacaja',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20609914069',
#   'Razón Social': 'AGROEXPORT PERU CORPORATION S.A.C',
#   'Tipo Empresa': 'Sociedad Anonima Cerrada',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '30 / Agosto / 2022',
#   'Actividad Comercial': 'Cultivo de Hortalizas y Legumbres.',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Computarizado',
#   'Tipo de Contabilidad': 'Computarizado',
#   'Dirección Legal': 'Av. Cementerio Nro. Sn (Altura Av. Evitamiento, 2 Cdras. Plaza.)',
#   'Distrito / Ciudad': 'Pazos',
#   'Provincia': 'Tayacaja',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20604466041',
#   'Razón Social': 'COMUNIDAD CAMPESINA DE QUISHUARCANCHA',
#   'Tipo Empresa': 'Comunidad Campesina Nativa',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '28 / Marzo / 2019',
#   'Actividades Comerciales': 'Cultivo de Hortalizas y Legumbres. Cultivos de Cereales.',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Manual/computarizado',
#   'Tipo de Contabilidad': 'Manual/computarizado',
#   'Dirección Legal': 'Cal. Quishuarcancha Nro. 1 ---- Cpme. Quishuarcancha',
#   'Distrito / Ciudad': 'Pazos',
#   'Provincia': 'Tayacaja',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20486383501',
#   'Razón Social': 'COMUNIDAD CAMPESINA SAN JOSE DE AYMARA',
#   'Tipo Empresa': 'Comunidad Campesina Nativa',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '05 / Octubre / 2023',
#   'Actividades Comerciales': 'Cultivo de Hortalizas y Legumbres. Cultivos de Cereales.',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Manual',
#   'Tipo de Contabilidad': 'Manual',
#   'Dirección Legal': 'Car. Principal Nro. Sn Anx. San Jose de Aymara (S68012144 Alt. Plaza San Jose de Aymara)',
#   'Distrito / Ciudad': 'Pazos',
#   'Provincia': 'Tayacaja',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20604771286',
#   'Razón Social': 'ASOCIACION DE PRODUCTORES AGROPECUARIOS JUDA PARIAC',
#   'Tipo Empresa': 'Asociacion',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '22 / Febrero / 2023',
#   'Actividad Comercial': 'Cultivo de Hortalizas y Legumbres.',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Computarizado',
#   'Tipo de Contabilidad': 'Computarizado',
#   'Dirección Legal': 'Pza. Principal Nro. Sn C.P. Pariac',
#   'Distrito / Ciudad': 'Roble',
#   'Provincia': 'Tayacaja',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20607121401',
#   'Razón Social': 'COMUNIDAD CAMPESINA DE BELLAVISTA LAUCA',
#   'Tipo Empresa': 'Comunidad Campesina Nativa',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '23 / Diciembre / 2020',
#   'Actividad Comercial': 'Cultivo de Hortalizas y Legumbres.',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Manual/computarizado',
#   'Tipo de Contabilidad': 'Manual/computarizado',
#   'Dirección Legal': 'Lote 3 Sec. Lauca Huaycco',
#   'Distrito / Ciudad': 'Salcabamba',
#   'Provincia': 'Tayacaja',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'},
#  {'RUC': '20611293306',
#   'Razón Social': 'ASOCIACION DE PRODUCTORES AGROPECUARIOS NUEVA REVELACION UNION MILLPO',
#   'Tipo Empresa': 'Asociacion',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '17 / Julio / 2023',
#   'Actividad Comercial': 'Cultivo de Hortalizas y Legumbres.',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Manual/computarizado',
#   'Tipo de Contabilidad': 'Manual/computarizado',
#   'Dirección Legal': 'Pza. Principal Nro. Sn Anx. Millpo (Alt. Plaza Distrito Surcubamba)',
#   'Distrito / Ciudad': 'Surcubamba',
#   'Provincia': 'Tayacaja',
#   'Departamento': 'Huancavelica, Perú'},
#  {'RUC': '20611622521',
#   'Razón Social': 'COMUNIDAD CAMPESINA DE SOCOS',
#   'Tipo Empresa': 'Comunidad Campesina Nativa',
#   'Condición': 'Activo',
#   'Fecha Inicio Actividades': '27 / Septiembre / 2023',
#   'Actividad Comercial': 'Cultivo de Hortalizas y Legumbres.',
#   'CIIU': '01123',
#   'Tipo de Facturación': 'Computarizado',
#   'Tipo de Contabilidad': 'Computarizado',
#   'Dirección Legal': 'Nro. Sn Anx. Socos',
#   'Distrito / Ciudad': 'Surcubamba',
#   'Provincia': 'Tayacaja',
#   'Departamento': 'Huancavelica, Perú',
#   'Estado Domicilio': 'Habido'}]
